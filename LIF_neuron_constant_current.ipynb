# %%
#Demonstrates the LIF neuron when stimulated with a constant current source


import numpy as np
import matplotlib.pyplot as plt
from LIF_neuron_constant_current import neuron_constant_current

#neuron model parameters
R = 1
C = 1
tau_m = R * C
u_rest = 0
u_threshold = 1
u_reset = u_rest
I = 1.5


#simulation parameters
dt = 0.01
t_max = 5


t, u = neuron_constant_current(R, C, tau_m, u_rest, u_threshold, u_reset, I, dt, t_max)

# Plot membrane potential
plt.plot(t, u, label='Membrane Potential')
plt.xlabel('Time')
plt.ylabel('Membrane Potential')
plt.title('Leaky Integrate-and-Fire Neuron')
plt.legend()
plt.grid(True)
plt.show()
